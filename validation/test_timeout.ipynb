# %% [markdown]
# # Test timeout feature

# %% [markdown]
# ## Table of content (ToC)<a class="anchor" id="TOC"></a>
# * <a href="#bullet1">1 - Introduction</a>
# * <a href="#bullet2">2 - Load the morphkit library</a>
# * <a href="#bullet3">3 - Load the morphkit library</a>
# * <a href="#bullet4">4 - Perform some tests</a>
# * <a href="#bullet5">5 - Required libraries</a>
# * <a href="#bullet6">6 - Test timeout to non-existing API endpoint</a>
# * <a href="#bullet7">7 - Notebook version</a>

# %% [markdown]
# #  1 - Introduction <a class="anchor" id="bullet1"></a>
# ##### [Back to ToC](#TOC)
#
# This Jupyter Notebook performs some test on the timeout feature.

# %% [markdown]
# # 2 - Resolve dependencies <a class="anchor" id="bullet2"></a>
# ##### [Back to ToC](#TOC)
#
# The morphkit package depends on beta code package.

# %%
# !pip install beta_code
# Out:
# Collecting beta_code
#   Downloading beta_code-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Downloading beta_code-1.1.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: beta_code
# Successfully installed beta_code-1.1.1

# %% [markdown]
# # 3 - Load the morphkit library <a class="anchor" id="bullet3"></a>
# ##### [Back to ToC](#TOC)

# %% [markdown]
# This is my own library (under development) available via [github.com/tonyjurg/morphkit](https://github.com/tonyjurg/morphkit). This is developed to simplify interactions with the Morpheus service running on my Docker container.

# %%
import sys
sys.path.insert(0, r"..\..\morphkit")    # relative to notebook dir
import morphkit
# Out:
# morphkit loaded

# %% [markdown]
# # 4 - Verify the changed functions <a class="anchor" id="bullet4"></a>
# ##### [Back to ToC](#TOC)
#
# We will first print the docstrings of the changed functions by calling `help()`.

# %%
help(morphkit.get_word_blocks)
# Out:
# Help on function get_word_blocks in module morphkit.get_word_blocks:
#
# get_word_blocks(word_beta: str, api_endpoint: str, language: str = 'greek', output: str = 'full', debug: bool = False, timeout: Union[int, float, NoneType] = None, retry_attempts: Optional[int] = None, retry_delay: Optional[float] = None) -> str
#     Retrieve the raw word blocks data for a given beta-code word from a Morpheus endpoint.
#
#     Args:
#     -----
#
#         :word_beta (str):        The input word in beta-code format to look up.
#                                  Backslashes in the input string need to be escaped: e.g., 'a)nh/r' -> 'a)nh/r\'
#
#         :api_endpoint (str):  IP adress & port of the  Morpheus API endpoint (e.g., '192.168.0.5:1315').
#
#         :language (str):    Optional argument. Defaults to `greek`. Sets the language of the word to analyse. It can be set to `greek` or `latin`.
#
#         :output {str}:      Optional argument. Defaults to `full`. Output format of the Analytic block. Either `full` for the internal database format, or `compact` for a brief output.
#
#         :debug (bool):      Optional argument. Defaults to `False`. If set to `True`, prints the constructed URL and response size.
#
#         :timeout (int|float|None): Optional argument. Defaults to config.timeout. Timeout in seconds for the request.
#
#         :retry_attempts (int): Optional argument. Defaults to config.retry_attempts. Number of retries on timeout/connection errors.
#
#         :retry_delay (float): Optional argument. Defaults to config.retry_delay. Delay between retries in seconds.
#
#     Returns:
#     --------
#
#         :str: The plain text response containing the word blocks for the requested beta-code form.
#
#     Raises:
#     -------
#
#         :ValueError: The language parameter is invalid (only 'greek' and 'latin' are allowed).
#
#         :ValueError: The api_endpoint parameter is malformed (format should be 'host(IP or name):port').
#
#         :requests.HTTPError: HTTP request failed (non-2xx status code).
#
#         :MorpheusTimeoutError: Request timed out after all retries.
#
#         :MorpheusConnectionError: Connection failed after all retries.
#
#     Example:
#     --------
#
#          .. code-block:: python
#
#             api_endpoint = "10.10.0.10:1315"
#             blocs=morphkit.get_word_blocks('sune/rxomai', api_endpoint)

# %%
help(morphkit.analyse_word_with_morpheus)
# Out:
# Help on function analyse_word_with_morpheus in module morphkit.analyse_word_with_morpheus:
#
# analyse_word_with_morpheus(word_beta: str, api_endpoint: str, language: str = 'greek', add_pos: bool = True, add_morph: bool = True, debug: bool = False, timeout: Optional[float] = None, retry_attempts: Optional[int] = None, retry_delay: Optional[float] = None) -> Dict[str, Any]
#     Query the Morpheus morphological analyser for a Greek word in Betacode and parse its analyses.
#
#     Args:
#     -----
#
#         :word_beta (str):     The input word in beta-code format to look up.
#                               Backslashes in the input need to be escaped: e.g., 'a)nh/r' -> 'a)nh/r\'.
#
#         :api_endpoint (str):  IP adress & port of the  Morpheus API endpoint (e.g., 192.168.0.5:1315).
#
#         :language (str):      Optional argument. Defaults to `greek`. The other option is 'latin'.
#                               If set to 'latin' no POS and morph field will be added.
#
#         :add_pos (bool):      Optional argument. Defaults to `True`. If set to `False` no POS field will be added to the parse.
#
#         :add_morph (bool):    Optional argument. Defaults to `True`. If set to `False` no morph field will be added to the parse.
#
#         :debug (bool):        Optional argument. Defaults to `False`. If set to `True` the function print some debug information.
#         :timeout (float|None): Optional argument. Defaults to config.timeout. Timeout in seconds for the request.
#         :retry_attempts (int): Optional argument. Defaults to config.retry_attempts. Number of retries on timeout/connection errors.
#         :retry_delay (float): Optional argument. Defaults to config.retry_delay. Delay between retries in seconds.
#
#     Returns:
#     --------
#
#         :Dict[str, Any]:   A dictionary with the following structure:
#
#             .. code-block:: python
#
#                 {
#                     'word': str,            # Normalized Betacode key returned by Morpheus
#                     'raw_uni': str,         # Unicode Greek of raw format (not returned when 'language=latin')
#                     'blocks': int,          # Number of blocks parsed
#                     'analyses': List[dict], # Parsed analyses from each block
#                 }
#
#     Steps:
#     ------
#
#       1. Fetch raw Morpheus output using function :py:func:`~morphkit.get_word_blocks`.
#       2. Split the response into analysis blocks at each ':raw' marker using function :py:func:`~morphkit.split_into_raw_blocks`.
#       3. For each block, call :py:func:`~morphkit.parse_word_block` to create a parse dictionairy.
#       4. Add Part of Speech tag to the parse dictionairy by calling :py:func:`~morphkit.analyse_pos`.
#       5. Add the SP morph-tag to the parse dictionairy by calling :py:func:`~morphkit.analyse_morph_tag`.
#       6. Return a structured result.
#
#     Raises:
#     -------
#
#     :ValueError: If the language parameter is invalid (only 'greek' and 'latin' are allowed).
#
#     :ValueError: If the api_endpoint parameter is malformed (format should be 'host(IP or name):port').
#
#     Example:
#     --------
#
#         .. code-block:: python
#
#             api_endpoint="192.168.0.5:1315"
#             result=morphkit.analyse_word_with_morpheus('au(/th',api_endpoint)
#
#
#     Flow diagram:
#     -------------
#
#     .. code-block:: none
#
#         +------------------------------+
#         | analyse_word_with_morpheus() |
#         +--------------+---------------+
#                        |
#                        v
#         +-----------------------+   HTTP request  +--------------------+
#         |  1. get word blocks   +<--------------->+  Morpheus endpoint |
#         +--------------+--------+  HTTP response  +--------------------+
#                        |
#                        v
#         +--------------+----------------+
#         | 2. Split into blocks          |
#         +-------------------------------+
#                        |
#                        v
#         +--------------+----------------+
#         | 3. for each block:            |
#         |     +----------------------+  |
#         |     | analyse_pos          |  |
#         |     | analyse_morph        |  |
#         |     +----------------------+  |
#         +--------------+----------------+
#                        |
#                        v
#         +--------------+----------------+
#         | 4. Return combined analyses   |
#         +-------------------------------+

# %% [markdown]
# # 5 - Perform some regression tests <a class="anchor" id="bullet5"></a>
# ##### [Back to ToC](#TOC)
#
# First, we will perform some regression testing (backward compatibility testing).

# %%
# convert unicode greek to betacode
import beta_code
bc_word=beta_code.greek_to_beta_code(u'Δία')
print (bc_word)
api_endpoint="10.0.1.156:1315" # IP/port
import pprint as pp
raw_text=morphkit.get_word_blocks(bc_word,api_endpoint,debug=True)
print(raw_text)
blocks=morphkit.split_into_raw_blocks(raw_text)
all_parses = []
for block in blocks:
    raw_beta, parses = morphkit.parse_word_block(block,debug=True)
    all_parses.append(parses)
    pp.pprint(parses)
# Out:
# *di/a
# [get_word_blocks] Sending GET request: http://10.0.1.156:1315/greek/%2Adi%2Fa?opts=d?opts=n
# [get_word_blocks] Received status code: 200
# [get_word_blocks] Response time: 0.025s
# [get_word_blocks] Request headers: {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive'}
# [get_word_blocks] Response headers: {'Content-Type': 'text/html;charset=utf-8', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Length': '1759'}
# [get_word_blocks] Response snippet (max 100 bytes):
#
# :raw *di/a
#
# :workw *di/a_
# :lem *di/h
# :prvb
# :aug1
# :stem *di	 fem sg			h_hs
# :suff
# :end...
#
# :raw *di/a
#
# :workw *di/a_
# :lem *di/h
# :prvb
# :aug1
# :stem *di	 fem sg			h_hs
# :suff
# :end a_	 fem nom/voc sg	doric aeolic		h_hs
#
# :raw *di/a
#
# :workw *di/a_
# :lem *di/h-pl
# :prvb
# :aug1
# :stem *di	 fem dual			h_hs
# :suff
# :end a_	 fem nom/voc/acc dual			h_hs
#
# :raw *di/a
#
# :workw *di/a
# :lem *di/on
# :prvb
# :aug1
# :stem *di	 neut			os_ou
# :suff
# :end a	 neut nom/voc/acc pl			os_ou
#
# :raw *di/a
#
# :workw *di=a
# :lem *di=a
# :prvb
# :aug1
# :stem *di_	 neut pl			os_ou
# :suff
# :end a	 neut nom/voc/acc pl			os_ou
#
# :raw *di/a
#
# :workw *di=a
# :lem *di=on
# :prvb
# :aug1
# :stem *di_	 neut		geog_name	os_ou
# :suff
# :end a	 neut nom/voc/acc pl			os_ou
#
# :raw *di/a
#
# :workw *dia=
# :lem *dieu/s
# :prvb
# :aug1
# :stem *di	 masc			eus_ews
# :suff
# :end a_	 masc acc sg	attic	contr r_e_i_alpha	eus_ews
#
# :raw *di/a
#
# :workw *di/a
# :lem *zeu/s
# :prvb
# :aug1
# :stem *di/a			indeclform
# :suff
# :end 	 masc acc sg		indeclform	irreg_decl3
#
# :raw *di/a
#
# :workw di=a
# :lem di=os
# :prvb
# :aug1
# :stem di=a			indeclform
# :suff
# :end 	 fem nom/voc sg	epic	indeclform	os_h_on
#
# :raw *di/a
#
# :workw di=a
# :lem di=os
# :prvb
# :aug1
# :stem di_				os_h_on
# :suff
# :end a	 neut nom/voc/acc pl			os_h_on
#
# :raw *di/a
#
# :workw di_/a_
# :lem di=os
# :prvb
# :aug1
# :stem di_				os_h_on
# :suff
# :end a_	 fem nom/voc/acc dual			os_h_on
#
# :raw *di/a
#
# :workw di_/a_
# :lem di=os
# :prvb
# :aug1
# :stem di_				os_h_on
# :suff
# :end a_	 fem nom/voc sg	doric aeolic		os_h_on
#
# :raw *di/a
#
# :workw di=a
# :lem di=os
# :prvb
# :aug1
# :stem di_		 *eur.		os_on
# :suff
# :end a	 neut nom/voc/acc pl			os_on
#
# :raw *di/a
#
# :workw dia/
# :lem dia/
# :prvb
# :aug1
# :stem dia/			indeclform
# :suff
# :end 			indeclform	prep
#
# [parse_word_block:betacode_to_polytonic] betacode_str='*di/h' greek='Δίη' oxia='Δίη'
# [{'case': ['nom', 'voc'],
#   'dialects': ['doric', 'aeolic'],
#   'end_bc': 'a_',
#   'end_codes': ['h_hs'],
#   'end_uc': 'α—',
#   'gender': 'fem',
#   'lem_base_bc': '*di/h',
#   'lem_base_uc': 'Δίη',
#   'lem_full_bc': '*di/h',
#   'lem_full_uc': 'Δίη',
#   'number': 'sg',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di',
#   'stem_codes': ['h_hs'],
#   'stem_gender': 'fem',
#   'stem_number': 'sg',
#   'stem_uc': 'Δι',
#   'workw_bc': '*di/a_',
#   'workw_uc': 'Δία—'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='*di/h-pl' greek='Δίη-πλ' oxia='Δίη-πλ'
# [{'case': ['nom', 'voc', 'acc'],
#   'end_bc': 'a_',
#   'end_codes': ['h_hs'],
#   'end_uc': 'α—',
#   'gender': 'fem',
#   'lem_base_bc': '*di/h',
#   'lem_base_uc': 'Δίη',
#   'lem_full_bc': '*di/h-pl',
#   'lem_full_uc': 'Δίη-πλ',
#   'lem_pl_suff': '1',
#   'number': 'dual',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di',
#   'stem_codes': ['h_hs'],
#   'stem_gender': 'fem',
#   'stem_number': 'dual',
#   'stem_uc': 'Δι',
#   'workw_bc': '*di/a_',
#   'workw_uc': 'Δία—'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='*di/on' greek='Δίον' oxia='Δίον'
# [{'case': ['nom', 'voc', 'acc'],
#   'end_bc': 'a',
#   'end_codes': ['os_ou'],
#   'end_uc': 'α',
#   'gender': 'neut',
#   'lem_base_bc': '*di/on',
#   'lem_base_uc': 'Δίον',
#   'lem_full_bc': '*di/on',
#   'lem_full_uc': 'Δίον',
#   'number': 'pl',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di',
#   'stem_codes': ['os_ou'],
#   'stem_gender': 'neut',
#   'stem_uc': 'Δι',
#   'workw_bc': '*di/a',
#   'workw_uc': 'Δία'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='*di=a' greek='Δῖα' oxia='Δῖα'
# [{'case': ['nom', 'voc', 'acc'],
#   'end_bc': 'a',
#   'end_codes': ['os_ou'],
#   'end_uc': 'α',
#   'gender': 'neut',
#   'lem_base_bc': '*di=a',
#   'lem_base_uc': 'Δῖα',
#   'lem_full_bc': '*di=a',
#   'lem_full_uc': 'Δῖα',
#   'number': 'pl',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di_',
#   'stem_codes': ['os_ou'],
#   'stem_gender': 'neut',
#   'stem_number': 'pl',
#   'stem_uc': 'Δι—',
#   'workw_bc': '*di=a',
#   'workw_uc': 'Δῖα'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='*di=on' greek='Δῖον' oxia='Δῖον'
# [{'case': ['nom', 'voc', 'acc'],
#   'end_bc': 'a',
#   'end_codes': ['os_ou'],
#   'end_uc': 'α',
#   'gender': 'neut',
#   'lem_base_bc': '*di=on',
#   'lem_base_uc': 'Δῖον',
#   'lem_full_bc': '*di=on',
#   'lem_full_uc': 'Δῖον',
#   'number': 'pl',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di_',
#   'stem_codes': ['os_ou'],
#   'stem_flags': ['geog_name'],
#   'stem_gender': 'neut',
#   'stem_uc': 'Δι—',
#   'workw_bc': '*di=a',
#   'workw_uc': 'Δῖα'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='*dieu/s' greek='Διεύς' oxia='Διεύς'
# [{'case': 'acc',
#   'dialects': ['attic'],
#   'end_bc': 'a_',
#   'end_codes': ['eus_ews'],
#   'end_flags': ['contr', 'r_e_i_alpha'],
#   'end_uc': 'α—',
#   'gender': 'masc',
#   'lem_base_bc': '*dieu/s',
#   'lem_base_uc': 'Διεύς',
#   'lem_full_bc': '*dieu/s',
#   'lem_full_uc': 'Διεύς',
#   'number': 'sg',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di',
#   'stem_codes': ['eus_ews'],
#   'stem_gender': 'masc',
#   'stem_uc': 'Δι',
#   'workw_bc': '*dia=',
#   'workw_uc': 'Διᾶ'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='*zeu/s' greek='Ζεύς' oxia='Ζεύς'
# [{'case': 'acc',
#   'end_codes': ['irreg_decl3'],
#   'end_flags': ['indeclform'],
#   'gender': 'masc',
#   'lem_base_bc': '*zeu/s',
#   'lem_base_uc': 'Ζεύς',
#   'lem_full_bc': '*zeu/s',
#   'lem_full_uc': 'Ζεύς',
#   'number': 'sg',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': '*di/a',
#   'stem_flags': ['indeclform'],
#   'stem_uc': 'Δία',
#   'workw_bc': '*di/a',
#   'workw_uc': 'Δία'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='di=os' greek='δῖος' oxia='δῖος'
# [{'case': ['nom', 'voc'],
#   'dialects': ['epic'],
#   'end_codes': ['os_h_on'],
#   'end_flags': ['indeclform'],
#   'gender': 'fem',
#   'lem_base_bc': 'di=os',
#   'lem_base_uc': 'δῖος',
#   'lem_full_bc': 'di=os',
#   'lem_full_uc': 'δῖος',
#   'number': 'sg',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': 'di=a',
#   'stem_flags': ['indeclform'],
#   'stem_uc': 'δῖα',
#   'workw_bc': 'di=a',
#   'workw_uc': 'δῖα'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='di=os' greek='δῖος' oxia='δῖος'
# [{'case': ['nom', 'voc', 'acc'],
#   'end_bc': 'a',
#   'end_codes': ['os_h_on'],
#   'end_uc': 'α',
#   'gender': 'neut',
#   'lem_base_bc': 'di=os',
#   'lem_base_uc': 'δῖος',
#   'lem_full_bc': 'di=os',
#   'lem_full_uc': 'δῖος',
#   'number': 'pl',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': 'di_',
#   'stem_codes': ['os_h_on'],
#   'stem_uc': 'δι—',
#   'workw_bc': 'di=a',
#   'workw_uc': 'δῖα'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='di=os' greek='δῖος' oxia='δῖος'
# [{'case': ['nom', 'voc', 'acc'],
#   'end_bc': 'a_',
#   'end_codes': ['os_h_on'],
#   'end_uc': 'α—',
#   'gender': 'fem',
#   'lem_base_bc': 'di=os',
#   'lem_base_uc': 'δῖος',
#   'lem_full_bc': 'di=os',
#   'lem_full_uc': 'δῖος',
#   'number': 'dual',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': 'di_',
#   'stem_codes': ['os_h_on'],
#   'stem_uc': 'δι—',
#   'workw_bc': 'di_/a_',
#   'workw_uc': 'δι— ́α—'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='di=os' greek='δῖος' oxia='δῖος'
# [{'case': ['nom', 'voc'],
#   'dialects': ['doric', 'aeolic'],
#   'end_bc': 'a_',
#   'end_codes': ['os_h_on'],
#   'end_uc': 'α—',
#   'gender': 'fem',
#   'lem_base_bc': 'di=os',
#   'lem_base_uc': 'δῖος',
#   'lem_full_bc': 'di=os',
#   'lem_full_uc': 'δῖος',
#   'number': 'sg',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': 'di_',
#   'stem_codes': ['os_h_on'],
#   'stem_uc': 'δι—',
#   'workw_bc': 'di_/a_',
#   'workw_uc': 'δι— ́α—'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='di=os' greek='δῖος' oxia='δῖος'
# [{'case': ['nom', 'voc', 'acc'],
#   'dialects': ['*eur.'],
#   'end_bc': 'a',
#   'end_codes': ['os_on'],
#   'end_uc': 'α',
#   'gender': 'neut',
#   'lem_base_bc': 'di=os',
#   'lem_base_uc': 'δῖος',
#   'lem_full_bc': 'di=os',
#   'lem_full_uc': 'δῖος',
#   'number': 'pl',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': 'di_',
#   'stem_codes': ['os_on'],
#   'stem_uc': 'δι—',
#   'workw_bc': 'di=a',
#   'workw_uc': 'δῖα'}]
# [parse_word_block:betacode_to_polytonic] betacode_str='dia/' greek='διά' oxia='διά'
# [{'end_codes': ['prep'],
#   'end_flags': ['indeclform'],
#   'lem_base_bc': 'dia/',
#   'lem_base_uc': 'διά',
#   'lem_full_bc': 'dia/',
#   'lem_full_uc': 'διά',
#   'raw_bc': '*di/a',
#   'raw_uc': 'Δία',
#   'stem_bc': 'dia/',
#   'stem_flags': ['indeclform'],
#   'stem_uc': 'διά',
#   'workw_bc': 'dia/',
#   'workw_uc': 'διά'}]

# %%
import pprint as pp
for [parse] in all_parses:  #[] since list of dictionaries
    parse['pos']=(morphkit.analyse_pos(parse,debug=True))
    pp.pprint(parse)
# Out:
# [analyse_pos] betacode *di/a:  word=None ordered_items=['h_hs', 'h_hs']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc'],
#  'dialects': ['doric', 'aeolic'],
#  'end_bc': 'a_',
#  'end_codes': ['h_hs'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': '*di/h',
#  'lem_base_uc': 'Δίη',
#  'lem_full_bc': '*di/h',
#  'lem_full_uc': 'Δίη',
#  'number': 'sg',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['h_hs'],
#  'stem_gender': 'fem',
#  'stem_number': 'sg',
#  'stem_uc': 'Δι',
#  'workw_bc': '*di/a_',
#  'workw_uc': 'Δία—'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['h_hs', 'h_hs']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a_',
#  'end_codes': ['h_hs'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': '*di/h',
#  'lem_base_uc': 'Δίη',
#  'lem_full_bc': '*di/h-pl',
#  'lem_full_uc': 'Δίη-πλ',
#  'lem_pl_suff': '1',
#  'number': 'dual',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['h_hs'],
#  'stem_gender': 'fem',
#  'stem_number': 'dual',
#  'stem_uc': 'Δι',
#  'workw_bc': '*di/a_',
#  'workw_uc': 'Δία—'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_ou', 'os_ou']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_ou'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': '*di/on',
#  'lem_base_uc': 'Δίον',
#  'lem_full_bc': '*di/on',
#  'lem_full_uc': 'Δίον',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['os_ou'],
#  'stem_gender': 'neut',
#  'stem_uc': 'Δι',
#  'workw_bc': '*di/a',
#  'workw_uc': 'Δία'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_ou', 'os_ou']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_ou'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': '*di=a',
#  'lem_base_uc': 'Δῖα',
#  'lem_full_bc': '*di=a',
#  'lem_full_uc': 'Δῖα',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di_',
#  'stem_codes': ['os_ou'],
#  'stem_gender': 'neut',
#  'stem_number': 'pl',
#  'stem_uc': 'Δι—',
#  'workw_bc': '*di=a',
#  'workw_uc': 'Δῖα'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_ou', 'os_ou', 'geog_name']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_ou'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': '*di=on',
#  'lem_base_uc': 'Δῖον',
#  'lem_full_bc': '*di=on',
#  'lem_full_uc': 'Δῖον',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di_',
#  'stem_codes': ['os_ou'],
#  'stem_flags': ['geog_name'],
#  'stem_gender': 'neut',
#  'stem_uc': 'Δι—',
#  'workw_bc': '*di=a',
#  'workw_uc': 'Δῖα'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['eus_ews', 'eus_ews', 'contr', 'r_e_i_alpha']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': 'acc',
#  'dialects': ['attic'],
#  'end_bc': 'a_',
#  'end_codes': ['eus_ews'],
#  'end_flags': ['contr', 'r_e_i_alpha'],
#  'end_uc': 'α—',
#  'gender': 'masc',
#  'lem_base_bc': '*dieu/s',
#  'lem_base_uc': 'Διεύς',
#  'lem_full_bc': '*dieu/s',
#  'lem_full_uc': 'Διεύς',
#  'number': 'sg',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['eus_ews'],
#  'stem_gender': 'masc',
#  'stem_uc': 'Δι',
#  'workw_bc': '*dia=',
#  'workw_uc': 'Διᾶ'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['irreg_decl3', 'indeclform', 'indeclform']
# [analyse_pos] indeclform+gender/number → proper noun indeclinable ~ N-PRI
# {'case': 'acc',
#  'end_codes': ['irreg_decl3'],
#  'end_flags': ['indeclform'],
#  'gender': 'masc',
#  'lem_base_bc': '*zeu/s',
#  'lem_base_uc': 'Ζεύς',
#  'lem_full_bc': '*zeu/s',
#  'lem_full_uc': 'Ζεύς',
#  'number': 'sg',
#  'pos': 'proper noun indeclinable',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di/a',
#  'stem_flags': ['indeclform'],
#  'stem_uc': 'Δία',
#  'workw_bc': '*di/a',
#  'workw_uc': 'Δία'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_h_on', 'indeclform', 'indeclform']
# [analyse_pos] indeclform+gender/number → proper noun indeclinable ~ N-PRI
# {'case': ['nom', 'voc'],
#  'dialects': ['epic'],
#  'end_codes': ['os_h_on'],
#  'end_flags': ['indeclform'],
#  'gender': 'fem',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'number': 'sg',
#  'pos': 'proper noun indeclinable',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di=a',
#  'stem_flags': ['indeclform'],
#  'stem_uc': 'δῖα',
#  'workw_bc': 'di=a',
#  'workw_uc': 'δῖα'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_h_on', 'os_h_on']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_h_on'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_h_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di=a',
#  'workw_uc': 'δῖα'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_h_on', 'os_h_on']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a_',
#  'end_codes': ['os_h_on'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'number': 'dual',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_h_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di_/a_',
#  'workw_uc': 'δι— ́α—'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_h_on', 'os_h_on']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc'],
#  'dialects': ['doric', 'aeolic'],
#  'end_bc': 'a_',
#  'end_codes': ['os_h_on'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'number': 'sg',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_h_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di_/a_',
#  'workw_uc': 'δι— ́α—'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['os_on', 'os_on']
# [analyse_pos] case or gender 🠢 noun ~ N-
# {'case': ['nom', 'voc', 'acc'],
#  'dialects': ['*eur.'],
#  'end_bc': 'a',
#  'end_codes': ['os_on'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di=a',
#  'workw_uc': 'δῖα'}
# [analyse_pos] betacode *di/a:  word=None ordered_items=['prep', 'indeclform', 'indeclform']
# [analyse_pos] ordered_items 🠢 preposition
# {'end_codes': ['prep'],
#  'end_flags': ['indeclform'],
#  'lem_base_bc': 'dia/',
#  'lem_base_uc': 'διά',
#  'lem_full_bc': 'dia/',
#  'lem_full_uc': 'διά',
#  'pos': 'preposition',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'dia/',
#  'stem_flags': ['indeclform'],
#  'stem_uc': 'διά',
#  'workw_bc': 'dia/',
#  'workw_uc': 'διά'}

# %%
import pprint as pp
for [parse] in all_parses:  #[] since list of dictionaries
    parse['morph']=(morphkit.analyse_morph_tag(parse,debug=True))
    pp.pprint(parse)
# Out:
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NSF-A/N-VSF-A
# {'case': ['nom', 'voc'],
#  'dialects': ['doric', 'aeolic'],
#  'end_bc': 'a_',
#  'end_codes': ['h_hs'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': '*di/h',
#  'lem_base_uc': 'Δίη',
#  'lem_full_bc': '*di/h',
#  'lem_full_uc': 'Δίη',
#  'morph': 'N-NSF-A/N-VSF-A',
#  'number': 'sg',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['h_hs'],
#  'stem_gender': 'fem',
#  'stem_number': 'sg',
#  'stem_uc': 'Δι',
#  'workw_bc': '*di/a_',
#  'workw_uc': 'Δία—'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NDF/N-VDF/N-ADF
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a_',
#  'end_codes': ['h_hs'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': '*di/h',
#  'lem_base_uc': 'Δίη',
#  'lem_full_bc': '*di/h-pl',
#  'lem_full_uc': 'Δίη-πλ',
#  'lem_pl_suff': '1',
#  'morph': 'N-NDF/N-VDF/N-ADF',
#  'number': 'dual',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['h_hs'],
#  'stem_gender': 'fem',
#  'stem_number': 'dual',
#  'stem_uc': 'Δι',
#  'workw_bc': '*di/a_',
#  'workw_uc': 'Δία—'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NPN/N-VPN/N-APN
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_ou'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': '*di/on',
#  'lem_base_uc': 'Δίον',
#  'lem_full_bc': '*di/on',
#  'lem_full_uc': 'Δίον',
#  'morph': 'N-NPN/N-VPN/N-APN',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['os_ou'],
#  'stem_gender': 'neut',
#  'stem_uc': 'Δι',
#  'workw_bc': '*di/a',
#  'workw_uc': 'Δία'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NPN/N-VPN/N-APN
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_ou'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': '*di=a',
#  'lem_base_uc': 'Δῖα',
#  'lem_full_bc': '*di=a',
#  'lem_full_uc': 'Δῖα',
#  'morph': 'N-NPN/N-VPN/N-APN',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di_',
#  'stem_codes': ['os_ou'],
#  'stem_gender': 'neut',
#  'stem_number': 'pl',
#  'stem_uc': 'Δι—',
#  'workw_bc': '*di=a',
#  'workw_uc': 'Δῖα'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NPN/N-VPN/N-APN
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_ou'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': '*di=on',
#  'lem_base_uc': 'Δῖον',
#  'lem_full_bc': '*di=on',
#  'lem_full_uc': 'Δῖον',
#  'morph': 'N-NPN/N-VPN/N-APN',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di_',
#  'stem_codes': ['os_ou'],
#  'stem_flags': ['geog_name'],
#  'stem_gender': 'neut',
#  'stem_uc': 'Δι—',
#  'workw_bc': '*di=a',
#  'workw_uc': 'Δῖα'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-ASM-ATT
# {'case': 'acc',
#  'dialects': ['attic'],
#  'end_bc': 'a_',
#  'end_codes': ['eus_ews'],
#  'end_flags': ['contr', 'r_e_i_alpha'],
#  'end_uc': 'α—',
#  'gender': 'masc',
#  'lem_base_bc': '*dieu/s',
#  'lem_base_uc': 'Διεύς',
#  'lem_full_bc': '*dieu/s',
#  'lem_full_uc': 'Διεύς',
#  'morph': 'N-ASM-ATT',
#  'number': 'sg',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di',
#  'stem_codes': ['eus_ews'],
#  'stem_gender': 'masc',
#  'stem_uc': 'Δι',
#  'workw_bc': '*dia=',
#  'workw_uc': 'Διᾶ'}
# [analyse_morph_tag] Called with betacode *di/a: prefix in indecl 🠢 N-PRI
# {'case': 'acc',
#  'end_codes': ['irreg_decl3'],
#  'end_flags': ['indeclform'],
#  'gender': 'masc',
#  'lem_base_bc': '*zeu/s',
#  'lem_base_uc': 'Ζεύς',
#  'lem_full_bc': '*zeu/s',
#  'lem_full_uc': 'Ζεύς',
#  'morph': 'N-PRI',
#  'number': 'sg',
#  'pos': 'proper noun indeclinable',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': '*di/a',
#  'stem_flags': ['indeclform'],
#  'stem_uc': 'Δία',
#  'workw_bc': '*di/a',
#  'workw_uc': 'Δία'}
# [analyse_morph_tag] Called with betacode *di/a: prefix in indecl 🠢 N-PRI
# {'case': ['nom', 'voc'],
#  'dialects': ['epic'],
#  'end_codes': ['os_h_on'],
#  'end_flags': ['indeclform'],
#  'gender': 'fem',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'morph': 'N-PRI',
#  'number': 'sg',
#  'pos': 'proper noun indeclinable',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di=a',
#  'stem_flags': ['indeclform'],
#  'stem_uc': 'δῖα',
#  'workw_bc': 'di=a',
#  'workw_uc': 'δῖα'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NPN/N-VPN/N-APN
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a',
#  'end_codes': ['os_h_on'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'morph': 'N-NPN/N-VPN/N-APN',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_h_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di=a',
#  'workw_uc': 'δῖα'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NDF/N-VDF/N-ADF
# {'case': ['nom', 'voc', 'acc'],
#  'end_bc': 'a_',
#  'end_codes': ['os_h_on'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'morph': 'N-NDF/N-VDF/N-ADF',
#  'number': 'dual',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_h_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di_/a_',
#  'workw_uc': 'δι— ́α—'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NSF-A/N-VSF-A
# {'case': ['nom', 'voc'],
#  'dialects': ['doric', 'aeolic'],
#  'end_bc': 'a_',
#  'end_codes': ['os_h_on'],
#  'end_uc': 'α—',
#  'gender': 'fem',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'morph': 'N-NSF-A/N-VSF-A',
#  'number': 'sg',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_h_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di_/a_',
#  'workw_uc': 'δι— ́α—'}
# [analyse_morph_tag] Called with betacode *di/a: noun/adjective/article 🠢 N-NPN/N-VPN/N-APN
# {'case': ['nom', 'voc', 'acc'],
#  'dialects': ['*eur.'],
#  'end_bc': 'a',
#  'end_codes': ['os_on'],
#  'end_uc': 'α',
#  'gender': 'neut',
#  'lem_base_bc': 'di=os',
#  'lem_base_uc': 'δῖος',
#  'lem_full_bc': 'di=os',
#  'lem_full_uc': 'δῖος',
#  'morph': 'N-NPN/N-VPN/N-APN',
#  'number': 'pl',
#  'pos': 'noun',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'di_',
#  'stem_codes': ['os_on'],
#  'stem_uc': 'δι—',
#  'workw_bc': 'di=a',
#  'workw_uc': 'δῖα'}
# [analyse_morph_tag] Called with betacode *di/a: prefix in indecl 🠢 PREP
# {'end_codes': ['prep'],
#  'end_flags': ['indeclform'],
#  'lem_base_bc': 'dia/',
#  'lem_base_uc': 'διά',
#  'lem_full_bc': 'dia/',
#  'lem_full_uc': 'διά',
#  'morph': 'PREP',
#  'pos': 'preposition',
#  'raw_bc': '*di/a',
#  'raw_uc': 'Δία',
#  'stem_bc': 'dia/',
#  'stem_flags': ['indeclform'],
#  'stem_uc': 'διά',
#  'workw_bc': 'dia/',
#  'workw_uc': 'διά'}

# %%
pp.pprint(morphkit.analyse_word_with_morpheus("puella",api_endpoint,language='latin',debug=True))
# Out:
# [analyse_word_with_morpheus] Calling function get_word_blocks(word_beta='puella',api_endpoint='10.0.1.156:1315',language='latin',debug=True,timeout=None,retry_attempts=None,retry_delay=None)
# [get_word_blocks] Sending GET request: http://10.0.1.156:1315/latin/puella?opts=d?opts=n
# [get_word_blocks] Received status code: 200
# [get_word_blocks] Response time: 0.097s
# [get_word_blocks] Request headers: {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive'}
# [get_word_blocks] Response headers: {'Content-Type': 'text/html;charset=utf-8', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Length': '252'}
# [get_word_blocks] Response snippet (max 100 bytes):
#
# :raw puella
#
# :workw puella_
# :lem puella
# :prvb
# :aug1
# :stem puell	 fem			a_ae
# :suff
# :e...
# [split_into_raw_blocks] function called
# Received 2 raw blocks
# [analyse_word_with_morpheus] Calling function parse_word_block(block,language='latin',debug=True) for block #1
# [analyse_word_with_morpheus] Parsed block 1 for betacode puella
# [analyse_word_with_morpheus] Calling function parse_word_block(block,language='latin',debug=True) for block #2
# [analyse_word_with_morpheus] Parsed block 2 for betacode puella
# {'analyses': [{'case': 'abl',
#                'end': 'a_',
#                'end_codes': ['a_ae'],
#                'gender': 'fem',
#                'lem_base': 'puella',
#                'lem_full': 'puella',
#                'number': 'sg',
#                'raw': 'puella',
#                'stem': 'puell',
#                'stem_codes': ['a_ae'],
#                'stem_gender': 'fem',
#                'workw': 'puella_'},
#               {'case': ['nom', 'voc'],
#                'end': 'a',
#                'end_codes': ['a_ae'],
#                'gender': 'fem',
#                'lem_base': 'puella',
#                'lem_full': 'puella',
#                'number': 'sg',
#                'raw': 'puella',
#                'stem': 'puell',
#                'stem_codes': ['a_ae'],
#                'stem_gender': 'fem',
#                'workw': 'puella'}],
#  'blocks': 2,
#  'raw_bc': 'puella'}

# %%
morphkit.analyse_word_with_morpheus("kai\\",api_endpoint,debug=False)
# Out:
# {'raw_bc': 'kai\\',
#  'raw_uc': 'καὶ',
#  'blocks': 1,
#  'analyses': [{'raw_bc': 'kai\\',
#    'raw_uc': 'καὶ',
#    'workw_bc': 'kai/',
#    'workw_uc': 'καί',
#    'lem_full_bc': 'kai/',
#    'lem_full_uc': 'καί',
#    'lem_base_bc': 'kai/',
#    'lem_base_uc': 'καί',
#    'stem_bc': 'kai/',
#    'stem_uc': 'καί',
#    'stem_flags': ['indeclform'],
#    'end_flags': ['indeclform'],
#    'end_codes': ['conj'],
#    'pos': 'conjunction',
#    'morph': 'CONJ'}]}

# %% [markdown]
# # 6 - Test timeout to non-existing API endpoint <a class="anchor" id="bullet6"></a>
# ##### [Back to ToC](#TOC)

# %%
raw_text=morphkit.get_word_blocks(bc_word,"10.0.1.150:1315",debug=True)
# Out:
# [get_word_blocks] Sending GET request: http://10.0.1.150:1315/greek/%2Adi%2Fa?opts=d?opts=n
# [get_word_blocks] Timeout; retry 1/3
# [get_word_blocks] Timeout; retry 2/3
# [get_word_blocks] Timeout; retry 3/3
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#
# File c:\Users\tonyj\anaconda3\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\tonyj\anaconda3\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File c:\Users\tonyj\anaconda3\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connection.py:208, in HTTPConnection._new_conn(self)
#     207 except SocketTimeout as e:
# --> 208     raise ConnectTimeoutError(
#     209         self,
#     210         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     211     ) from e
#     213 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x000001EF3FB7AF90>, 'Connection to 10.0.1.150 timed out. (connect timeout=30)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\tonyj\anaconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='10.0.1.150', port=1315): Max retries exceeded with url: /greek/%2Adi%2Fa?opts=d?opts=n (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001EF3FB7AF90>, 'Connection to 10.0.1.150 timed out. (connect timeout=30)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File d:\Onedrive\GitHub\morphkit\validation\..\..\morphkit\morphkit\get_word_blocks.py:156, in get_word_blocks(word_beta, api_endpoint, language, output, debug, timeout, retry_attempts, retry_delay)
#     154 try:
#     155     # 2. Perform the HTTP GET request
# --> 156     resp = requests.get(url, timeout=timeout)
#     157     elapsed = time.perf_counter() - start
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\tonyj\anaconda3\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPConnectionPool(host='10.0.1.150', port=1315): Max retries exceeded with url: /greek/%2Adi%2Fa?opts=d?opts=n (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001EF3FB7AF90>, 'Connection to 10.0.1.150 timed out. (connect timeout=30)'))
#
# The above exception was the direct cause of the following exception:
#
# MorpheusTimeoutError                      Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 raw_text=morphkit.get_word_blocks(bc_word,"10.0.1.150:1315",debug=True)
#
# File d:\Onedrive\GitHub\morphkit\validation\..\..\morphkit\morphkit\get_word_blocks.py:191, in get_word_blocks(word_beta, api_endpoint, language, output, debug, timeout, retry_attempts, retry_delay)
#     189             time.sleep(retry_delay)
#     190         continue
# --> 191     raise MorpheusTimeoutError(
#     192         f"Request timed out after {timeout} seconds (attempts: {retry_attempts + 1})."
#     193     ) from e
#     194 except requests.exceptions.ConnectionError as e:
#     195     last_error = e
#
# MorpheusTimeoutError: Request timed out after 30 seconds (attempts: 4).

# %%
raw_text=morphkit.get_word_blocks(bc_word,"10.0.1.150:1315",debug=False)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#
# File ~\anaconda3\envs\Text-Fabric\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File ~\anaconda3\envs\Text-Fabric\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connection.py:208, in HTTPConnection._new_conn(self)
#     207 except SocketTimeout as e:
# --> 208     raise ConnectTimeoutError(
#     209         self,
#     210         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     211     ) from e
#     213 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x0000020D262B7A70>, 'Connection to 10.0.1.150 timed out. (connect timeout=30)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='10.0.1.150', port=1315): Max retries exceeded with url: /greek/%2Adi%2Fa?opts=d?opts=n (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020D262B7A70>, 'Connection to 10.0.1.150 timed out. (connect timeout=30)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File D:\test\morphkit\get_word_blocks.py:154, in get_word_blocks(word_beta, api_endpoint, language, output, debug, timeout, retry_attempts, retry_delay)
#     152 try:
#     153     # 2. Perform the HTTP GET request
# --> 154     resp = requests.get(url, timeout=timeout)
#     155     elapsed = time.perf_counter() - start
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPConnectionPool(host='10.0.1.150', port=1315): Max retries exceeded with url: /greek/%2Adi%2Fa?opts=d?opts=n (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x0000020D262B7A70>, 'Connection to 10.0.1.150 timed out. (connect timeout=30)'))
#
# The above exception was the direct cause of the following exception:
#
# MorpheusTimeoutError                      Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 raw_text=morphkit.get_word_blocks(bc_word,"10.0.1.150:1315",debug=False)
#
# File D:\test\morphkit\get_word_blocks.py:189, in get_word_blocks(word_beta, api_endpoint, language, output, debug, timeout, retry_attempts, retry_delay)
#     187             time.sleep(retry_delay)
#     188         continue
# --> 189     raise MorpheusTimeoutError(
#     190         f"Request timed out after {timeout} seconds (attempts: {retry_attempts + 1})."
#     191     ) from e
#     192 except requests.exceptions.ConnectionError as e:
#     193     last_error = e
#
# MorpheusTimeoutError: Request timed out after 30 seconds (attempts: 4).

# %% [markdown]
# # Test optional paramater

# %% [markdown]
# In earlier runs responce times are reported like:
# <pre>
# [get_word_blocks] Response time: 0.037s
# </pre>
# To force timeout scenairo, we will set the timeout to be significantly lower.

# %%
bc_word=beta_code.greek_to_beta_code(u'Δία')
api_endpoint="10.0.1.156:1315" # IP/port
raw_text=morphkit.get_word_blocks(bc_word,api_endpoint,timeout=0.005,debug=True)
# Out:
# [get_word_blocks] Sending GET request: http://10.0.1.156:1315/greek/%2Adi%2Fa?opts=d?opts=n
# [get_word_blocks] Timeout; retry 1/3
# [get_word_blocks] Received status code: 200
# [get_word_blocks] Response time: 0.042s
# [get_word_blocks] Request headers: {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive'}
# [get_word_blocks] Response headers: {'Content-Type': 'text/html;charset=utf-8', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Length': '1759'}
# [get_word_blocks] Response snippet (max 100 bytes):
#
# :raw *di/a
#
# :workw *di/a_
# :lem *di/h
# :prvb
# :aug1
# :stem *di	 fem sg			h_hs
# :suff
# :end...

# %%
raw_text=morphkit.get_word_blocks(bc_word,api_endpoint,timeout=0.0001,debug=True)
# Out:
# [get_word_blocks] Sending GET request: http://10.0.1.156:1315/greek/%2Adi%2Fa?opts=d?opts=n
# [get_word_blocks] Timeout; retry 1/3
# [get_word_blocks] Timeout; retry 2/3
# [get_word_blocks] Timeout; retry 3/3
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\urllib3\connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPConnectionPool(host='10.0.1.156', port=1315): Read timed out. (read timeout=0.0001)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File D:\test\morphkit\get_word_blocks.py:154, in get_word_blocks(word_beta, api_endpoint, language, output, debug, timeout, retry_attempts, retry_delay)
#     152 try:
#     153     # 2. Perform the HTTP GET request
# --> 154     resp = requests.get(url, timeout=timeout)
#     155     elapsed = time.perf_counter() - start
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\envs\Text-Fabric\Lib\site-packages\requests\adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPConnectionPool(host='10.0.1.156', port=1315): Read timed out. (read timeout=0.0001)
#
# The above exception was the direct cause of the following exception:
#
# MorpheusTimeoutError                      Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 raw_text=morphkit.get_word_blocks(bc_word,api_endpoint,timeout=0.0001,debug=True)
#
# File D:\test\morphkit\get_word_blocks.py:189, in get_word_blocks(word_beta, api_endpoint, language, output, debug, timeout, retry_attempts, retry_delay)
#     187             time.sleep(retry_delay)
#     188         continue
# --> 189     raise MorpheusTimeoutError(
#     190         f"Request timed out after {timeout} seconds (attempts: {retry_attempts + 1})."
#     191     ) from e
#     192 except requests.exceptions.ConnectionError as e:
#     193     last_error = e
#
# MorpheusTimeoutError: Request timed out after 0.0001 seconds (attempts: 4).

# %% [markdown]
# # 5 - Notebook version<a class="anchor" id="bullet5"></a>
# ##### [Back to ToC](#TOC)
#
# <div style="float: left;">
#   <table>
#     <tr>
#       <td><strong>Author</strong></td>
#       <td>Tony Jurg</td>
#     </tr>
#     <tr>
#       <td><strong>Version</strong></td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <td><strong>Date</strong></td>
#       <td>January 14, 2026</td>
#     </tr>
#   </table>
# </div>
